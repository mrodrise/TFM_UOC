# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">Trabajo final de master</p>
# <p style="margin: 0; text-align:right;">Máster universitario en Ciencia de datos (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
#
# # Estado de la computación cuántica en el aprendizaje por refuerzo y cómo aplicarla en DQN y Reinforce con Línea Base
#
# ## QVC aplicado a DQN en entorno Acrobot

# %% [markdown]
# Se importan las librerías necesarias para ejecutar el Jupyter Notebook

# %%
# Importamos timeit para tomar mediciones de tiempo de ejecución
import timeit

# Importamos codecarbon para tomar medidas de huella de carbono
from codecarbon import EmissionsTracker

# %%
import sys
# Para importar nuestras librerías, que están en otro directorio
sys.path.append("../librerias")

# Librería con circuito cuántico definido
import QVC

# Modelos de aprendizaje por refuerzo
import Model

# Experience Replay Buffer para DQN
import experienceReplayBuffer as erb

# Agentes
import Agent

# %%
# Se importa la librería gymnasium para utilizar los entornos CartPole y Acrobot
import gym as gym

# %% [markdown]
# Se crea el entorno, en este caso Acrobot

# %%
env = gym.envs.make("Acrobot-v1")
# Out:
# /Users/marcoemiliorodriguezserrano/anaconda3/lib/python3.10/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/marcoemiliorodriguezserrano/anaconda3/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# Se definen los hiperparámetros que se utilizarán en el modelo de aprendizaje por refuerzo

# %%
# Hiperparámetros del modelo de aprendizaje por refuerzo
lr = 0.001            #Velocidad de aprendizaje
MEMORY_SIZE = 10000  #Máxima capacidad del buffer
MAX_EPISODES = 1500   #Número máximo de episodios (el agente debe aprender antes de llegar a este valor)
EPSILON = 1           #Valor inicial de epsilon
EPSILON_DECAY = .99   #Decaimiento de epsilon
GAMMA = 0.99          #Valor gamma de la ecuación de Bellman
BATCH_SIZE = 32       #Conjunto a coger del buffer para la red neuronal
BURN_IN = 1000        #Número de episodios iniciales usados para rellenar el buffer antes de entrenar
DNN_UPD = 50          #Frecuencia de actualización de la red neuronal
DNN_SYNC = 500     #Frecuencia de sincronización de pesos entre la red neuronal y la red objetivo

# %% [markdown]
# Se definen los hiperparámetros del circuito QVC

# %%
# Hiperparámetros del QVC
n_layers = 5    # número de capas del Ansatz
n_qubits = 6    # qubits definidos, en este caso son 6 al disponer de 6 variables de observación
n_actions = 3   # número de acciones, se definen 3 para Acrobot
environment = 1 # entorno Acrobot
quantum_device = "default.qubit" # dispositivo cuántico, se define un simulador cuántico

# %% [markdown]
# Se crea el buffer de repetición de experiencias

# %%
buffer = erb.experienceReplayBuffer(memory_size=MEMORY_SIZE, burn_in=BURN_IN)   # buffer experience replay

# %% [markdown]
# Se define el circuito cuántico que sustituye a la red neuronal

# %%
net = QVC.QuantumNet(n_layers, n_qubits, n_actions, environment, quantum_device)

# %% [markdown]
# Se crea la red objetivo también como un circuito cuántico

# %%
target_network = QVC.QuantumNet(n_layers, n_qubits, n_actions, environment, quantum_device)

# %% [markdown]
# Se crea el modelo DQN

# %%
dqn = Model.DQN(env, net, learning_rate=lr)

# %% [markdown]
# Se crea el modelo DQN objetivo

# %%
dqn_target = Model.DQN(env, target_network, learning_rate=lr)

# %% [markdown]
# Se crea el agente, se le pasa como parámetro los dos modelos inicializados que contienen un circuito cuántico

# %%
agent = Agent.DQNAgent(env, dqn, dqn_target, buffer, EPSILON, EPSILON_DECAY, BATCH_SIZE)

# %% [markdown]
# Se prepara el entorno para iniciar las mediciones de CO2

# %%
# Se define la carpeta de salida de los archivos de emisiones
output_dir = './emisiones/emisiones_QVC_DQN_Acrobot'

# Se crea una instancia de EmissionsTracker y se configura la carpeta de salida
tracker = EmissionsTracker(output_dir=output_dir, log_level = "critical")

# Se inicializa el seguimiento de las emisiones
#tracker.start()

# %% [markdown]
# Iniciamos el cronómetro para medir el tiempo del proceso

# %%
tiempo_inicio = timeit.default_timer()

# %% [markdown]
# Se inicia el entrenamiento del agente

# %%
agent.train(gamma=GAMMA, max_episodes=MAX_EPISODES,
              batch_size=BATCH_SIZE, dnn_update_frequency=DNN_UPD, dnn_sync_frequency=DNN_SYNC)
# Out:
# Rellenando el buffer de repetición...
# Entrenando...
# Episodio 11 Recompensa media -500.00 Epsilon 0.9043820750088043
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 agent.train(gamma=GAMMA, max_episodes=MAX_EPISODES,
#       2               batch_size=BATCH_SIZE, dnn_update_frequency=DNN_UPD, dnn_sync_frequency=DNN_SYNC)
#
# File ~/PycharmProjects/TFM_UOC/cuadernos_jupyter/../librerias/Agent.py:82, in DQNAgent.train(self, gamma, max_episodes, batch_size, dnn_update_frequency, dnn_sync_frequency)
#      80 # Actualizamos la red principal según la frecuencia establecida
#      81 if self.step_count % dnn_update_frequency == 0:
# ---> 82     self.update()
#      84 # Sincronizamos la red principal y la red objetivo según la frecuencia establecida
#      85 if self.step_count % dnn_sync_frequency == 0:
#
# File ~/PycharmProjects/TFM_UOC/cuadernos_jupyter/../librerias/Agent.py:151, in DQNAgent.update(self)
#     147 self.dnnetwork.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
#     149 batch = self.buffer.sample_batch(batch_size=self.batch_size)  # seleccionamos un conjunto del buffer
# --> 151 loss = self.calculate_loss(batch)  # calculamos la pérdida
#     153 loss.backward()  # hacemos la diferencia para obtener los gradientes
#     155 self.dnnetwork.optimizer.step()  # aplicamos los gradientes a la red neuronal
#
# File ~/PycharmProjects/TFM_UOC/cuadernos_jupyter/../librerias/Agent.py:129, in DQNAgent.calculate_loss(self, batch)
#     126 dones_t = torch.BoolTensor(dones).to(device=self.dnnetwork.device)
#     128 # Obtenemos los valores de Q de la red principal
# --> 129 qvals = torch.gather(self.dnnetwork.get_qvals(states), 1, actions_vals)
#     131 # Obtenemos los valores de Q objetivo. El parámetro detach() evita que estos valores actualicen la red objetivo
#     132 qvals_next = torch.max(self.target_network.get_qvals(next_states),
#     133                        dim=-1)[0].detach()
#
# File ~/PycharmProjects/TFM_UOC/cuadernos_jupyter/../librerias/Model.py:44, in DQN.get_qvals(self, state)
#      42     state = np.array([np.ravel(s) for s in state])
#      43 state_t = torch.FloatTensor(state).to(device=self.device)
# ---> 44 return self.model(state_t)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/PycharmProjects/TFM_UOC/cuadernos_jupyter/../librerias/QVC.py:126, in QuantumNet.forward(self, inputs)
#     123     inputs[4] = torch.atan(inputs[4])
#     124     inputs[5] = torch.atan(inputs[5])
# --> 126 outputs = self.q_layers(inputs)
#     127 outputs = (1 + outputs) / 2
#     130 if self.environment == 0:  # Cartpole
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnn/torch.py:309, in TorchLayer.forward(self, inputs)
#     295 """Evaluates a forward pass through the QNode based upon input data and the initialized
#     296 weights.
#     297
#    (...)
#     302     tensor: output data
#     303 """
#     305 if len(inputs.shape) > 1:
#     306     # If the input size is not 1-dimensional, unstack the input along its first dimension,
#     307     # recursively call the forward pass on each of the yielded tensors, and then stack the
#     308     # outputs back into the correct shape
# --> 309     reconstructor = [self.forward(x) for x in torch.unbind(inputs)]
#     310     return torch.stack(reconstructor)
#     312 # If the input is 1-dimensional, calculate the forward pass as usual
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnn/torch.py:309, in <listcomp>(.0)
#     295 """Evaluates a forward pass through the QNode based upon input data and the initialized
#     296 weights.
#     297
#    (...)
#     302     tensor: output data
#     303 """
#     305 if len(inputs.shape) > 1:
#     306     # If the input size is not 1-dimensional, unstack the input along its first dimension,
#     307     # recursively call the forward pass on each of the yielded tensors, and then stack the
#     308     # outputs back into the correct shape
# --> 309     reconstructor = [self.forward(x) for x in torch.unbind(inputs)]
#     310     return torch.stack(reconstructor)
#     312 # If the input is 1-dimensional, calculate the forward pass as usual
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnn/torch.py:313, in TorchLayer.forward(self, inputs)
#     310     return torch.stack(reconstructor)
#     312 # If the input is 1-dimensional, calculate the forward pass as usual
# --> 313 return self._evaluate_qnode(inputs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnn/torch.py:328, in TorchLayer._evaluate_qnode(self, x)
#     316 """Evaluates the QNode for a single input datapoint.
#     317
#     318 Args:
#    (...)
#     322     tensor: output datapoint
#     323 """
#     324 kwargs = {
#     325     **{self.input_arg: x},
#     326     **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     327 }
# --> 328 res = self.qnode(**kwargs)
#     330 if isinstance(res, torch.Tensor):
#     331     return res.type(x.dtype)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnode.py:867, in QNode.__call__(self, *args, **kwargs)
#     865     self.execute_kwargs.pop("mode")
#     866 # pylint: disable=unexpected-keyword-arg
# --> 867 res = qml.execute(
#     868     [self.tape],
#     869     device=self.device,
#     870     gradient_fn=self.gradient_fn,
#     871     interface=self.interface,
#     872     gradient_kwargs=self.gradient_kwargs,
#     873     override_shots=override_shots,
#     874     **self.execute_kwargs,
#     875 )
#     877 res = res[0]
#     879 if old_interface == "auto":
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:407, in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     403     return batch_fn(res)
#     405 if gradient_fn == "backprop" or interface is None:
#     406     return batch_fn(
# --> 407         qml.interfaces.cache_execute(
#     408             batch_execute, cache, return_tuple=False, expand_fn=expand_fn
#     409         )(tapes)
#     410     )
#     412 # the default execution function is batch_execute
#     413 execute_fn = qml.interfaces.cache_execute(batch_execute, cache, expand_fn=expand_fn)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:204, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     200         return (res, []) if return_tuple else res
#     202 else:
#     203     # execute all unique tapes that do not exist in the cache
# --> 204     res = fn(execution_tapes.values(), **kwargs)
#     206 final_res = []
#     208 for i, tape in enumerate(tapes):
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:130, in cache_execute.<locals>.fn(tapes, **kwargs)
#     128 def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     129     tapes = [expand_fn(tape) for tape in tapes]
# --> 130     return original_fn(tapes, **kwargs)
#
# File ~/anaconda3/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_qubit_device.py:588, in QubitDevice.batch_execute(self, circuits)
#     583 for circuit in circuits:
#     584     # we need to reset the device here, else it will
#     585     # not start the next computation in the zero state
#     586     self.reset()
# --> 588     res = self.execute(circuit)
#     589     results.append(res)
#     591 if self.tracker.active:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit_torch.py:232, in DefaultQubitTorch.execute(self, circuit, **kwargs)
#     224         if params_cuda_device != specified_device_cuda:
#     225             warnings.warn(
#     226                 f"Torch device {self._torch_device} specified "
#     227                 "upon PennyLane device creation does not match the "
#     228                 "Torch device of the gate parameters; "
#     229                 f"{self._torch_device} will be used."
#     230             )
# --> 232 return super().execute(circuit, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_qubit_device.py:318, in QubitDevice.execute(self, circuit, **kwargs)
#     315 self.check_validity(circuit.operations, circuit.observables)
#     317 # apply all circuit operations
# --> 318 self.apply(circuit.operations, rotations=self._get_diagonalizing_gates(circuit), **kwargs)
#     320 # generate computational basis samples
#     321 if self.shots is not None or circuit.is_sampled:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:276, in DefaultQubit.apply(self, operations, rotations, **kwargs)
#     274         self._state = self._apply_parametrized_evolution(self._state, operation)
#     275     else:
# --> 276         self._state = self._apply_operation(self._state, operation)
#     278 # store the pre-rotated state
#     279 self._pre_rotated_state = self._state
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:316, in DefaultQubit._apply_operation(self, state, operation)
#     313     axes = [ax + shift for ax in self.wires.indices(wires)]
#     314     return self._apply_ops[operation.base_name](state, axes)
# --> 316 matrix = self._asarray(self._get_unitary_matrix(operation), dtype=self.C_DTYPE)
#     318 if operation in diagonal_in_z_basis:
#     319     return self._apply_diagonal_unitary(state, matrix, wires)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit_torch.py:304, in DefaultQubitTorch._get_unitary_matrix(self, unitary)
#     302 if unitary in diagonal_in_z_basis:
#     303     return self._asarray(unitary.eigvals(), dtype=self.C_DTYPE)
# --> 304 return self._asarray(unitary.matrix(), dtype=self.C_DTYPE)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/operation.py:745, in Operator.matrix(self, wire_order)
#     725 def matrix(self, wire_order=None):
#     726     r"""Representation of the operator as a matrix in the computational basis.
#     727
#     728     If ``wire_order`` is provided, the numerical representation considers the position of the
#    (...)
#     743         tensor_like: matrix representation
#     744     """
# --> 745     canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     747     if wire_order is None or self.wires == Wires(wire_order):
#     748         return canonical_matrix
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py:100, in RX.compute_matrix(theta)
#      79 @staticmethod
#      80 def compute_matrix(theta):  # pylint: disable=arguments-differ
#      81     r"""Representation of the operator as a canonical matrix in the computational basis (static method).
#      82
#      83     The canonical matrix is the textbook matrix representation that does not consider wires.
#    (...)
#      98             [0.0000-0.2474j, 0.9689+0.0000j]])
#      99     """
# --> 100     c = qml.math.cos(theta / 2)
#     101     s = qml.math.sin(theta / 2)
#     103     if qml.math.get_interface(theta) == "tensorflow":
#
# File ~/anaconda3/lib/python3.10/site-packages/autoray/autoray.py:78, in do(fn, like, *args, **kwargs)
#      29 def do(fn, *args, like=None, **kwargs):
#      30     """Do function named ``fn`` on ``(*args, **kwargs)``, peforming single
#      31     dispatch to retrieve ``fn`` based on whichever library defines the class of
#      32     the ``args[0]``, or the ``like`` keyword argument if specified.
#    (...)
#      76         <tf.Tensor: id=91, shape=(3, 3), dtype=float32>
#      77     """
# ---> 78     backend = choose_backend(fn, *args, like=like, **kwargs)
#      79     return get_lib_fn(backend, fn)(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/autoray/autoray.py:336, in choose_backend(fn, like, *args, **kwargs)
#     328 """Choose a backend based on function name, arguments, and the ``like``
#     329 keyword argument. The default, if ``like`` is not specified, is to infer
#     330 the backend from the function call, the default of which is simply to use
#    (...)
#     333 backend name or an arbitrary object.
#     334 """
#     335 if like is None:
# --> 336     return _infer_auto(fn, *args, **kwargs)
#     337 elif isinstance(like, str):
#     338     return like
#
# File ~/anaconda3/lib/python3.10/site-packages/autoray/autoray.py:91, in _default_infer_from_sig(fn, *args, **kwargs)
#      85 def _default_infer_from_sig(fn, *args, **kwargs):
#      86     """This is the default backend dispatcher, used if no global backend has
#      87     been set. Hot swapping this function out as below avoids having to check
#      88     manually for a global backend or worse, a thread aware global backend, on
#      89     every call to ``do``.
#      90     """
# ---> 91     return _DISPATCHERS[fn](*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Se calcula el tiempo de ejecución, lo que ha tardado el agente en entrenar

# %%
tiempo_ejecucion = round(timeit.default_timer() - tiempo_inicio, 0)
print("Tiempo ejecución entrenamiento: " + str(int(tiempo_ejecucion/3600))
      + " horas, " + str(int((tiempo_ejecucion % 3600)/60)) + " minutos y "
      + str(int((tiempo_ejecucion % 3600)%60)) + " segundos")

# %% [markdown]
# Se calculan las emisiones que han podido implicar el proceso

# %%
#emisiones = tracker.stop()
#print("Emisiones de CO2 (Kg)" + str(emisiones))

# %% [markdown]
# Se procede a graficar los resultados

# %%
agent.plot_rewards()
agent.plot_loss()
